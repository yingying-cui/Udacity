# %% [markdown]
# # Similarity Analysis on Roman Amphorae

# %% [markdown]
# ## Step 1: Business understanding

# %% [markdown]
# In ancient Rome, large ceramic containers called amphorae were used to transport goods like olive oil and wine. One of the most common types, Dressel 20 amphorae, was mainly used for shipping olive oil from Spain to different parts of the Roman Empire. These amphorae were produced in workshops, where craftsmen shaped and fired the clay to create standardized containers.
#
# This study examines 413 Dressel 20 amphorae found at five different workshops.
#
# Using data analysis and modeling to explore the shape and size of these amphorae, this project aims to uncover patterns that show whether these workshops influenced each other or operated in isolation.

# %% [markdown]
# The dataset used in this project came from this paper:
#
# Coto-Sarmiento, M., Rubio-Campillo, X., Remesal, J. (2018): Identifying social learning between Roman amphorae workshops through morphometric similarity, Journal of Archaeological Science, 96, pp. 117–123, doi: https://doi.org/10.1016/j.jas.2018.06.002

# %% [markdown]
# ## Step 2: Data understanding

# %%
# install

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 7
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
# ----> 7 import scikit_learn as sklearn
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'scikit_learn'

# %%
df = pd.read_csv(r"D:\personal docs\UdacityDS\Course2\dataDressel.csv")

# %%
df.head()
# Out:
#    number excavation       type chronology  exterior_diam  inside_diam  rim_h  \
# 0       1   delicias  Dressel B          A            150          120     44
# 1       2   delicias  Dressel B          A            140          102     46
# 2       3   delicias  Dressel B          A            150          110     45
# 3       4   delicias  Dressel E          C            180           90     35
# 4       5   delicias  Dressel B          A            130           86     44
#
#    rim_w  shape_w  rim_inside_h  rim_w_2  protruding_rim      site
# 0     24       11            40        9              40  delicias
# 1     30        7            45       16              39  delicias
# 2     25       11            41       22              36  delicias
# 3     40       14            28       35               9  delicias
# 4     27       12            36       17              32  delicias

# %%
df.shape
# Out:
# (470, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number          470 non-null    int64
#  1   excavation      470 non-null    object
#  2   type            470 non-null    object
#  3   chronology      462 non-null    object
#  4   exterior_diam   470 non-null    int64
#  5   inside_diam     470 non-null    int64
#  6   rim_h           470 non-null    int64
#  7   rim_w           470 non-null    int64
#  8   shape_w         470 non-null    int64
#  9   rim_inside_h    470 non-null    int64
#  10  rim_w_2         470 non-null    int64
#  11  protruding_rim  470 non-null    int64
#  12  site            470 non-null    object
# dtypes: int64(9), object(4)
# memory usage: 47.9+ KB

# %%
for col in df.select_dtypes(exclude=int):
    print(f'Column {col} contains {df[col].value_counts()}')
# Out:
# Column excavation contains excavation
# delicias      128
# malpica       111
# belen          89
# parlamento     84
# villaseca      58
# Name: count, dtype: int64
# Column type contains type
# Dressel D     198
# Dressel E     172
# Dressel C      55
# Dressel B      24
# Dressel G      14
# Dressel 23      7
# Name: count, dtype: int64
# Column chronology contains chronology
# B      198
# C      185
# A-B     55
# A       24
# Name: count, dtype: int64
# Column site contains site
# delicias      128
# malpica       111
# belen          89
# parlamento     84
# villaseca      58
# Name: count, dtype: int64

# %%
check_equal = df['excavation'].equals(df['site'])
print(check_equal)
# Out:
# True

# %%
df.describe()
# Out:
#            number  exterior_diam  inside_diam       rim_h       rim_w  \
# count  470.000000     470.000000   470.000000  470.000000  470.000000
# mean    50.548936     166.889362    94.474468   35.391489   36.293617
# std     31.830520      12.840189    10.050108    3.583296    4.758895
# min      1.000000     120.000000    70.000000   25.000000   15.000000
# 25%     24.000000     160.000000    90.000000   34.000000   34.000000
# 50%     47.500000     170.000000    90.000000   35.000000   37.000000
# 75%     74.000000     175.000000   100.000000   37.000000   40.000000
# max    128.000000     210.000000   140.000000   56.000000   48.000000
#
#           shape_w  rim_inside_h     rim_w_2  protruding_rim
# count  470.000000    470.000000  470.000000      470.000000
# mean     9.512766     28.380851   30.348936       18.889362
# std      1.358401      3.564462    5.376006        6.608815
# min      5.000000     18.000000    7.000000        5.000000
# 25%      9.000000     26.000000   28.000000       14.000000
# 50%     10.000000     28.000000   31.000000       18.000000
# 75%     10.000000     30.000000   34.000000       23.000000
# max     14.000000     45.000000   44.000000       42.000000

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# chronology        8
# number            0
# excavation        0
# type              0
# exterior_diam     0
# inside_diam       0
# rim_h             0
# rim_w             0
# shape_w           0
# rim_inside_h      0
# rim_w_2           0
# protruding_rim    0
# site              0
# dtype: int64

# %% [markdown]
# ### Basic understanding

# %% [markdown]
# Column 'number' is the ID for each Dressel 20 vessel discovered among 5 sites (delicias, malpica, belen, parlamento, and villaseca), so the data type should be `str`. However, since this column serves as ID column instead of feature, it can be dropped in feature selection.
#
# Column 'excavation' has exact alignment with column 'site', which means all vessels were discovered where they were made. For feature selection, one of them can be dropped.
#
# There are 8 missing values at column 'chronology' in the dataset.taset.set.

# %% [markdown]
# ### Univariate analysis

# %%
num_features = df.select_dtypes(include='int').columns.to_list()
cat_features = [col for col in df.columns if (col != 'number') and (col not in num_features)]
print(f'Numerical features include {num_features}')
print(f'Categorical features include {cat_features}')
# Out:
# Numerical features include ['number', 'exterior_diam', 'inside_diam', 'rim_h', 'rim_w', 'shape_w', 'rim_inside_h', 'rim_w_2', 'protruding_rim']
# Categorical features include ['excavation', 'type', 'chronology', 'site']

# %%
for col in num_features:
    plt.figure(figsize=(6,4))
    sns.boxplot(y=df[col], color="blue")
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
for col in cat_features:
    plt.figure(figsize=(6,4))
    sns.countplot(x=df[col], order=df[col].value_counts().index, hue=df[col], legend=False)
    plt.ylabel("Count")
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# ### Bivariate analysis

# %%
for col in num_features:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
    plt.title(f"Distribution of {col} by site")
    plt.show()
# Out:
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")
# C:\Users\evang\AppData\Local\Temp\ipykernel_3976\2025465169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='chronology', y=col, data=df, palette="viridis")

# %%
for col in cat_features:
    if col != 'excavation' and col != 'chronology':
        plt.figure(figsize=(6,4))
        sns.histplot(data=df, x=col, y='chronology', hue='chronology', shrink=0.8)
        plt.title(f"Chronology distribution per {col}")
        plt.ylabel("Count")
        plt.show()

# %% [markdown]
# ### Multivariate analysis

# %%
corr_matrix = df[num_features].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Step 3: Data preparation

# %%
# Impute missing values with the most frequent value (mode)

most_frequent_value = df['chronology'].mode()[0]
df['chronology'] = df['chronology'].fillna(most_frequent_value)

# %%
df.isna().sum()
# Out:
# number            0
# excavation        0
# type              0
# chronology        0
# exterior_diam     0
# inside_diam       0
# rim_h             0
# rim_w             0
# shape_w           0
# rim_inside_h      0
# rim_w_2           0
# protruding_rim    0
# site              0
# dtype: int64

# %%
# encoding chronology using OrdinalEncoder

from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

chronology_order = [['A', 'A-B', 'B', 'C']]
ordinal_encoder = OrdinalEncoder(categories=chronology_order)
df['chronology_encoded'] = ordinal_encoder.fit_transform(df[['chronology']])

# encoding site and type using one-oot encoding
df = pd.get_dummies(df, columns=['site', 'type'])

# %%
df.columns
# Out:
# Index(['number', 'excavation', 'chronology', 'exterior_diam', 'inside_diam',
#        'rim_h', 'rim_w', 'shape_w', 'rim_inside_h', 'rim_w_2',
#        'protruding_rim', 'chronology_encoded', 'site_belen', 'site_delicias',
#        'site_malpica', 'site_parlamento', 'site_villaseca', 'type_Dressel 23',
#        'type_Dressel B', 'type_Dressel C', 'type_Dressel D', 'type_Dressel E',
#        'type_Dressel G'],
#       dtype='object')

# %%
#feature selection

df_model = df.drop(['excavation', 'number'], axis=1)

# %%
df_model.columns
# Out:
# Index(['chronology', 'exterior_diam', 'inside_diam', 'rim_h', 'rim_w',
#        'shape_w', 'rim_inside_h', 'rim_w_2', 'protruding_rim',
#        'chronology_encoded', 'site_belen', 'site_delicias', 'site_malpica',
#        'site_parlamento', 'site_villaseca', 'type_Dressel 23',
#        'type_Dressel B', 'type_Dressel C', 'type_Dressel D', 'type_Dressel E',
#        'type_Dressel G'],
#       dtype='object')

# %% [markdown]
# ## Step 4: Modeling

# %%
from sklearn.model_selection import train_test_split

X = df_model.drop(['chronology', 'chronology_encoded'], axis=1).copy()
y = df_model['chronology'].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ## Step 5: Evaluation

# %%
from sklearn.metrics import classification_report, accuracy_score

y_pred = model.predict(X_test)

# Evaluate the model
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00         7
#          A-B       1.00      1.00      1.00        18
#            B       1.00      1.00      1.00        50
#            C       1.00      1.00      1.00        66
#
#     accuracy                           1.00       141
#    macro avg       1.00      1.00      1.00       141
# weighted avg       1.00      1.00      1.00       141

# %%
feature_importances = model.feature_importances_

importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
})

importance_df = importance_df.sort_values(by='Importance', ascending=False)
print(importance_df)
# Out:
#             Feature  Importance
# 16   type_Dressel D    0.341031
# 17   type_Dressel E    0.265085
# 15   type_Dressel C    0.140905
# 14   type_Dressel B    0.043001
# 3             rim_w    0.041217
# 0     exterior_diam    0.030964
# 6           rim_w_2    0.030536
# 18   type_Dressel G    0.017490
# 2             rim_h    0.015873
# 5      rim_inside_h    0.015515
# 7    protruding_rim    0.012880
# 13  type_Dressel 23    0.012654
# 1       inside_diam    0.010566
# 11  site_parlamento    0.008914
# 4           shape_w    0.006360
# 12   site_villaseca    0.003079
# 10     site_malpica    0.001678
# 8        site_belen    0.001488
# 9     site_delicias    0.000766

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': np.arange(100, 501, 100),  # 100, 200, 300, 400, 500
    'max_depth': np.arange(10, 51, 10),         # 10, 20, 30, 40, 50
    'min_samples_split': np.arange(2, 11, 2),   # 2, 4, 6, 8, 10
    'min_samples_leaf': np.arange(1, 11, 2)     # 1, 3, 5, 7, 9
}

rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf,
                           param_grid=param_grid,
                           cv=3,        # 3-fold cross-validation
                           n_jobs=-1,   # Use all available CPU cores
                           verbose=2)   # Print progress

# Fit the model to the training data
grid_search.fit(X_train, y_train)

# Get the best parameters and model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print(f"Best Parameters: {best_params}")
# Out:
# Fitting 3 folds for each of 625 candidates, totalling 1875 fits
# Best Parameters: {'max_depth': np.int64(10), 'min_samples_leaf': np.int64(1), 'min_samples_split': np.int64(2), 'n_estimators': np.int64(100)}

# %%
# Predictions using the best model
y_pred_best = best_model.predict(X_test)

# Evaluate the model
print(f"Accuracy: {accuracy_score(y_test, y_pred_best)}")
print("Classification Report:")
print(classification_report(y_test, y_pred_best))
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00         7
#          A-B       1.00      1.00      1.00        18
#            B       1.00      1.00      1.00        50
#            C       1.00      1.00      1.00        66
#
#     accuracy                           1.00       141
#    macro avg       1.00      1.00      1.00       141
# weighted avg       1.00      1.00      1.00       141

# %%
feature_importances_best = best_model.feature_importances_

importance_df_best = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances_best
})

importance_df_best = importance_df_best.sort_values(by='Importance', ascending=False)
print(importance_df_best)
# Out:
#             Feature  Importance
# 16   type_Dressel D    0.338268
# 17   type_Dressel E    0.265880
# 15   type_Dressel C    0.142161
# 14   type_Dressel B    0.043202
# 3             rim_w    0.042032
# 6           rim_w_2    0.031178
# 0     exterior_diam    0.031170
# 18   type_Dressel G    0.017436
# 5      rim_inside_h    0.015433
# 2             rim_h    0.015391
# 7    protruding_rim    0.013350
# 13  type_Dressel 23    0.012371
# 1       inside_diam    0.010019
# 11  site_parlamento    0.009069
# 4           shape_w    0.006153
# 12   site_villaseca    0.003149
# 10     site_malpica    0.001511
# 8        site_belen    0.001383
# 9     site_delicias    0.000844
